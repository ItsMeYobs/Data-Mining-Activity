# %% [markdown]
# <a href="https://colab.research.google.com/github/ItsMeYobs/Data-Mining-Activity/blob/main/Lecture_10_Choosing_Effective_Visuals_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture 10 - Choosing Effective Visuals Part 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# This session will focus on the science of visualization.  Data Visualization is the graphical representation of information and data.  Using these tools provides an accessible way to understand patterns in the data.

# %% [markdown]
# ## Import Libraries and Load Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

#dataset = pd.read_csv("/content/drive/MyDrive/CS172/Home Dataset/data.csv")
#dataset1 = pd.read_csv("/content/drive/MyDrive/CS172/data.csv")
url = '/content/data.csv'
dataset = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-60213357dbe7> in <cell line: 7>()
#       5 #dataset1 = pd.read_csv("/content/drive/MyDrive/CS172/data.csv")
#       6 url = '/content/data.csv'
# ----> 7 dataset = pd.read_csv(url)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# ## Simple Text

# %% [markdown]
# When you have just a number or two to share, simple text can be a
# great way to communicate. Think about solely using the number—
# making it as prominent as possible—and a few supporting words
# to clearly make your point.

# %%
print("Average Lot Area in the Dataset", dataset['LotArea'].mean().round())
# Out:
# Average Lot Area in the Dataset 9819.0

# %% [markdown]
# When you have more data that you want to show, generally a table
# or graph is the way to go. One thing to understand is that people
# interact differently with these two types of visuals.

# %% [markdown]
# ## Heatmap

# %% [markdown]
# One approach for mixing the detail you can include in a table while
# also making use of visual cues is via a heatmap. A heatmap is a way
# to visualize data in tabular format, where in place of (or in addition
# to) the numbers, you leverage colored cells that convey the relative
# magnitude of the numbers.

# %%
# subset dataset
subset = dataset[['LotArea','LotFrontage']]
subset.head()
# Out:
#    LotArea  LotFrontage
# 0    11622         80.0
# 1    14267         81.0
# 2    13830         74.0
# 3     9978         78.0
# 4     5005         43.0

# %%
# heatmap
subset.loc[0:5].style.background_gradient(cmap="summer")
# Out:
# <style type="text/css">
# #T_d377b_row0_col0 {
#   background-color: #b6db66;
#   color: #000000;
# }
# #T_d377b_row0_col1 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_d377b_row1_col0, #T_d377b_row1_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d377b_row2_col0 {
#   background-color: #f3f966;
#   color: #000000;
# }
# #T_d377b_row2_col1 {
#   background-color: #d0e866;
#   color: #000000;
# }
# #T_d377b_row3_col0 {
#   background-color: #89c466;
#   color: #000000;
# }
# #T_d377b_row3_col1 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_d377b_row4_col0, #T_d377b_row4_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_d377b_row5_col0 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_d377b_row5_col1 {
#   background-color: #d7eb66;
#   color: #000000;
# }
# </style>
# <table id="T_d377b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
datacorr = dataset.corr()
# Out:
# <ipython-input-18-066b147d201b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datacorr = dataset.corr()

# %%
plt.imshow(datacorr, cmap="inferno")
plt.colorbar()

# %%
datacorr
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.004993     0.009930  0.051492    -0.064887
# MSSubClass     0.004993    1.000000    -0.450505 -0.359537     0.034690
# LotFrontage    0.009930   -0.450505     1.000000  0.644608     0.182870
# LotArea        0.051492   -0.359537     0.644608  1.000000     0.107989
# OverallQual   -0.064887    0.034690     0.182870  0.107989     1.000000
# OverallCond    0.009553   -0.071768    -0.092312 -0.103402    -0.095874
# YearBuilt     -0.058647    0.040848     0.122356  0.048314     0.621910
# YearRemodAdd  -0.079437    0.046319     0.092603  0.036907     0.591267
# MasVnrArea    -0.021424   -0.012186     0.251533  0.188691     0.453991
# BsmtFinSF1    -0.045966   -0.058775     0.204621  0.185470     0.322583
# BsmtFinSF2     0.015862   -0.079093     0.046824  0.054199    -0.028199
# BsmtUnfSF      0.001203   -0.111080     0.092031  0.071681     0.243070
# ...

# %% [markdown]
# In the first table, you are left to read the data. You need to scan across rows and columns to get a sense of the data.  To reduce this mental processing, we can use color saturation to provide visual cues, helping our eyes and brains more quickly target the potential points of interest.

# %% [markdown]
# While tables interact with our verbal system, graphs interact with
# our visual system, which is faster at processing information. This
# means that a well‐designed graph will typically get the information
# across more quickly than a well‐designed table.

# %% [markdown]
# ## Scatterplot

# %% [markdown]
# Scatterplots can be useful for showing the relationship between two things, because they allow you to encode data simultaneously on a horizontal x‐axis and vertical y‐axis to see whether and what relationship exists. They tend to be more frequently used in scientific fields *(and perhaps, because of this, are sometimes viewed as complicated to understand by those less familiar with them)*.

# %%
subset.plot.scatter(x="LotFrontage", y="LotArea", alpha=.2, color="green")
plt.title("LotArea vs LotFrontage");

# %%
plt.scatter(subset['LotFrontage'], subset['LotArea'])
plt.xlabel("LotFrontage")
plt.ylabel("LotArea")
plt.title("LotArea vs LotFrontage");
